# %%
print(11222)
# Out:
# 11222

# %%
a = 1
b = 2
print(a + b)
# Out:
# 3

# %%
from pyperclip import copy
text = """

数据加密技术在计算机网络安全存储中的应用方法
密钥管理技术在计算机网络安全存储中的应用方法
数据备份技术在计算机网络安全存储中的应用方法
应用可恢复性数据算法
"""
copy(''.join([i for i in text if i!=' ' and i!='\n']))

# %%
import os

# %%
print(ord('🂡'))
begin = ord('🂡')

for i in range(131071, 160000):
    print(chr(i), i, end=',')
# Out:
# 127137
# ...
